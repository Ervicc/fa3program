# %% [markdown]
# <a href="https://colab.research.google.com/github/Ervicc/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
name = input("What is your name? ")
age = input("How old are you? ")
course = input("What is your course? ")

print(f"Name:{name}")
print(f"Age:{age}")
print(f"Course:{course}")
# Out:
# What is your name? Ervic
# How old are you? 13
# What is your course? ComSci
# Name:Ervic
# Age:13
# Course:ComSci

# %%
#fa3prog2

score = input("What is your score? ")
score = int(score)

if score >= 75:
    print("Passed")
else:
    print("Failed")
# Out:
# What is your score? 71
# Failed

# %%
#fa3prog3

score = input("What is your score? ")
score = int(score)

if score >= 90:
  print("A")
elif score >= 80:
  print("B")
elif score >= 70:
  print("C")
else:
  print("F")
# Out:
# What is your score? 67
# F
